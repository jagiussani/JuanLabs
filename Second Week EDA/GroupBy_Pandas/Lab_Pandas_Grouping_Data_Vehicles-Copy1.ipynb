# %% [markdown]
# # Pandas: grouping

# %%
import pandas as pd
import numpy as np

# %%
cars = pd.read_csv("/Users/juanandresgiussani/Documents/GitHub/IH_DA_FT_MAR_2023/Class_Materials/Pandas/data/vehicles.csv")

# %%
cars.head(10)
# Out:
#                Make                Model  Year  Engine Displacement  \
# 0        AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1        AM General     FJ8c Post Office  1984                  4.2
# 2        AM General  Post Office DJ5 2WD  1985                  2.5
# 3        AM General  Post Office DJ8 2WD  1985                  4.2
# 4  ASC Incorporated                  GNX  1987                  3.8
# 5             Acura          2.2CL/3.0CL  1997                  2.2
# 6             Acura          2.2CL/3.0CL  1997                  2.2
# 7             Acura          2.2CL/3.0CL  1997                  3.0
# 8             Acura          2.3CL/3.0CL  1998                  2.3
# 9             Acura          2.3CL/3.0CL  1998                  2.3
#
#    Cylinders     Transmission         Drivetrain                Vehicle Class  \
# 0        4.0  Automatic 3-spd      2-Wheel Drive  Special Purpose Vehicle 2WD
# ...

# %% [markdown]
# How many Car models?

# %%
#3608 should be the answer


set_of_cars = set(cars['Model'].unique())
len(set_of_cars)

##would not work:
# cars['Model'].unique() 
# sum(cars.groupcby("Model").groups)
# Out:
# 3608

# %%
# This also works
cars['Model'].nunique()
# Out:
# 3608

# %% [markdown]
# group by the data by the Make  using count function

# %%
cars.groupby(["Make", "Model"]).count()
# Out:
#                                       Year  Engine Displacement  Cylinders  \
# Make             Model
# AM General       DJ Po Vehicle 2WD       1                    1          1
#                  FJ8c Post Office        1                    1          1
#                  Post Office DJ5 2WD     1                    1          1
#                  Post Office DJ8 2WD     1                    1          1
# ASC Incorporated GNX                     1                    1          1
# ...                                    ...                  ...        ...
# Yugo             GV/GVX                  3                    3          3
#                  Gy/yugo GVX             1                    1          1
# smart            fortwo cabriolet        8                    8          8
#                  fortwo convertible      2                    2          2
#                  fortwo coupe           10                   10         10
#
# ...

# %% [markdown]
# Converting Grams/Mile to Grams/Km
#
# 1 Mile = 1.60934 Km
#
# Converting Gallons to Liters
#
# 1 Gallon = 3.78541 Liters

# %% [markdown]
# What brand has the most cars?

# %%
cars["Make"].mode()
# Chevrolet is the most common value seen in the column 'Make'
# Out:
# 0    Chevrolet
# Name: Make, dtype: object

# %% [markdown]
# <b>show the average CO2_Emission_Grams/Km  by Brand

# %%
cars['CO2 Emission Grams/Km'] = cars['CO2 Emission Grams/Mile']*1.60934

# %%
cars.groupby(['Make','CO2 Emission Grams/Mile']).mean()
# Out:
#                                             Year  Engine Displacement  \
# Make             CO2 Emission Grams/Mile
# AM General       522.764706               1984.0                  2.5
#                  555.437500               1985.0                  2.5
#                  683.615385               1984.5                  4.2
# ASC Incorporated 555.437500               1987.0                  3.8
# Acura            228.000000               2013.5                  1.5
# ...                                          ...                  ...
# smart            246.000000               2016.0                  0.9
#                  246.861111               2010.0                  1.0
#                  251.000000               2017.0                  0.9
#                  255.000000               2016.0                  0.9
#                  258.000000               2017.0                  0.9
#
#                                           Cylinders  Fuel Barrels/Year  \
# ...

# %% [markdown]
# <b>show the average CO2_Emission_Grams/Km  by Brand ... sorted

# %%
cars.groupby(['Make','CO2 Emission Grams/Km']).mean().sort_values('CO2 Emission Grams/Km')
# Out:
#                                       Year  Engine Displacement  Cylinders  \
# Make        CO2 Emission Grams/Km
# BMW         59.545580              2016.00                 0.60        2.0
#             64.373600              2014.50                 0.60        2.0
# Chevrolet   82.076340              2016.50                 1.50        4.0
#             130.356540             2014.00                 1.40        4.0
#             135.184560             2011.00                 1.40        4.0
# ...                                    ...                  ...        ...
# Rolls-Royce 1787.775572            1986.25                 6.80        8.0
# Vector      1787.775572            1992.50                 6.00        8.0
# Ferrari     1787.775572            1999.00                 5.35       12.0
# Maserati    1787.775572            1985.50                 4.90        8.0
# Lamborghini 2043.172083            1988.00                 5.20       12.0
#
# ...

# %% [markdown]
# # (Optional)

# %% [markdown]
# Use `pd.cut` or `pd.qcut` to create 4 groups (bins) of cars, by Year. We want to explore how cars have evolved decade by decade.

# %%
cars['Year'].describe()
# Out:
# count    35952.00000
# mean      2000.71640
# std         10.08529
# min       1984.00000
# 25%       1991.00000
# 50%       2001.00000
# 75%       2010.00000
# max       2017.00000
# Name: Year, dtype: float64

# %%
## your code here

# %% [markdown]
# ### Did cars consume more gas in the eighties?

# %% [markdown]
# show the average City_Km/Liter by year_range

# %%
### your code is here

# %% [markdown]
# Which brands are more environment friendly?

# %%
### your code is here
# Out:
#                                     CO2_Emission_Grams/Km
# Decade Brand
# 80s    AMG                                     379.881345
#        ASC                                     345.133719
#        Acura                                   268.497682
#        Alfa Romeo                              286.715163
#        American Motors Corporation             314.264744
# ...                                                   ...
# 10s    Volkswagen                              219.440984
#        Volvo                                   250.429309
#        Wallace Environmental                          NaN
#        Yugo                                           NaN
#        smart                                   153.509751
#
# [488 rows x 1 columns]

# %% [markdown]
# Does the drivetrain affect fuel consumption?

# %%
## Your Code here
# Out:
#                             Highway_Km/Liter  City_Km/Liter
# Drivetrain
# 2-Wheel Drive, Front               14.029714      10.628571
# Front-Wheel Drive                  12.166210       9.002214
# All-Wheel Drive                    10.882531       7.785598
# 4-Wheel Drive                       9.668584       7.190861
# 2-Wheel Drive                       8.222444       6.642480
# Rear-Wheel Drive                    9.023946       6.556574
# 4-Wheel or All-Wheel Drive          8.347130       6.392049
# Part-time 4-Wheel Drive             8.115385       6.215696

# %% [markdown]
# Do cars with automatic transmission consume more fuel than cars with manual transmission?

# %%
## Your Code here
# Out:
#            City_Km/Liter
# Trans
# Manual          7.968348
# Automatic       7.278292

# %% [markdown]
# Use `groupby` and `agg` with different aggregation measures for different columns:

# %% [markdown]
# aggregate with average City_Km/Liter and the count of the Trans

# %%
## your code is here
# Out:
#            City_Km/Liter  Trans
# Trans
# Automatic       7.278292  24290
# Manual          7.968348  11662

# %% [markdown]
# aggregate with average City_Km/Liter and the minimum of the Trans

# %%
### your code is here
# Out:
#            City_Km/Liter
# Trans
# Automatic       2.976000
# Manual          2.550857
